# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# reproducibility (tidak 100% deterministik di GPU tapi membantu)
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("tensorflow:", tf.__version__)
# Out:
# numpy: 1.23.5
# pandas: 2.3.3
# tensorflow: 2.12.0

# %%
BASE_DIR = r"c:\Users\X395\kuliah semester 5\TUGAS 4"
CSV_PATH = os.path.join(BASE_DIR, "btc_15m_data_2018_to_2025.csv")  # ganti jika file lain
MODEL_H5 = os.path.join(BASE_DIR, "lstm_btc_daily_model.h5")
MODEL_SAVED = os.path.join(BASE_DIR, "model_saved_tf")
SCALER_PATH = os.path.join(BASE_DIR, "scaler_minmax.joblib")

TIMESTEPS = 60
VAL_RATIO = 0.2
BATCH_SIZE = 32
EPOCHS = 100

# %%
df = pd.read_csv(CSV_PATH)
display(df.head())
print("\nKolom dataset:", df.columns.tolist())
# Out:
#                      Open time      Open      High       Low     Close  \
# 0  2018-01-01 00:00:00.000000   13715.65  13715.65  13400.01  13556.15
# 1  2018-01-01 00:15:00.000000   13533.75  13550.87  13402.00  13521.12
# 2  2018-01-01 00:30:00.000000   13500.00  13545.37  13450.00  13470.41
# 3  2018-01-01 00:45:00.000000   13494.65  13690.87  13450.00  13529.01
# 4  2018-01-01 01:00:00.000000   13528.99  13571.74  13402.28  13445.63
#
#        Volume                   Close time  Quote asset volume  \
# 0  123.616013  2018-01-01 00:14:59.999000         1.675545e+06
# 1   98.136430  2018-01-01 00:29:59.999000         1.321757e+06
# 2   79.904037  2018-01-01 00:44:59.999000         1.078825e+06
# 3  141.699719  2018-01-01 00:59:59.999000         1.917783e+06
# 4   72.537533  2018-01-01 01:14:59.999000         9.778198e+05
#
#    Number of trades  Taker buy base asset volume  \
# 0              1572                    63.227133
# 1              1461                    47.686389
# 2              1000                    43.710406
# 3              1195                    73.897993
# 4               898                    34.257652
#
#    Taker buy quote asset volume  Ignore
# 0                  8.576108e+05       0
# 1                  6.422812e+05       0
# 2                  5.900347e+05       0
# 3                  1.000614e+06       0
# 4                  4.618369e+05       0
# Kolom dataset: ['Open time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close time', 'Quote asset volume', 'Number of trades', 'Taker buy base asset volume', 'Taker buy quote asset volume', 'Ignore']

# %%
time_col = None
for c in df.columns:
    if c.lower() in ("open time", "timestamp", "date", "datetime"):
        time_col = c; break
if time_col is None:
    raise ValueError(f"Tidak menemukan kolom waktu. Kolom: {df.columns.tolist()}")

df[time_col] = pd.to_datetime(df[time_col])
df = df.sort_values(by=time_col).set_index(time_col)
print("Range:", df.index.min(), "->", df.index.max())
display(df[['Close']].head())
# Out:
# Range: 2018-01-01 00:00:00 -> 2025-10-15 23:15:00
#                         Close
# Open time
# 2018-01-01 00:00:00  13556.15
# 2018-01-01 00:15:00  13521.12
# 2018-01-01 00:30:00  13470.41
# 2018-01-01 00:45:00  13529.01
# 2018-01-01 01:00:00  13445.63

# %%
if "Close" not in df.columns:
    raise ValueError("Kolom 'Close' tidak ditemukan.")
daily = df['Close'].resample('D').last().dropna()
plt.figure(figsize=(12,5))
daily.plot()
plt.title("Harga Penutupan Bitcoin - Harian (Last Close Per Day)")
plt.xlabel("Tanggal"); plt.ylabel("Harga (USD)"); plt.grid(True); plt.show()

data = daily.to_frame(name='Close').astype(float)
display(data.head())
print("Jumlah baris (harian):", len(data))
print("Missing values:\n", data.isna().sum())
display(data.describe())
# Out:
#                Close
# Open time
# 2018-01-01  13380.00
# 2018-01-02  14675.11
# 2018-01-03  14919.51
# 2018-01-04  15059.54
# 2018-01-05  16960.39
# Jumlah baris (harian): 2845
# Missing values:
#  Close    0
# dtype: int64
#                Close
# count    2845.000000
# mean    35662.265023
# std     31100.258769
# min      3211.720000
# 25%      9339.050000
# 50%     26705.920000
# 75%     53962.970000
# max    124658.540000

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(data[['Close']].values)  # (n,1)
print("Scaled shape:", scaled.shape)
# Out:
# Scaled shape: (2845, 1)

# %%
def make_dataset(values, window=60):
    X, y = [], []
    for i in range(window, len(values)):
        X.append(values[i-window:i, 0])
        y.append(values[i, 0])
    return np.array(X), np.array(y)

X, y = make_dataset(scaled, TIMESTEPS)
X = X.reshape((X.shape[0], X.shape[1], 1))   # (samples, timesteps, features=1)
print("Shape X:", X.shape, " Shape y:", y.shape)
# Out:
# Shape X: (2785, 60, 1)  Shape y: (2785,)

# %%
train_size = int(len(X) * (1 - VAL_RATIO))
X_train, X_val = X[:train_size], X[train_size:]
y_train, y_val = y[:train_size], y[train_size:]
print("Train samples:", X_train.shape[0], " Val samples:", X_val.shape[0])
# Out:
# Train samples: 2228  Val samples: 557

# %%
from tensorflow.keras import layers, Model, Input

# Ambil timesteps dari dataset (X.shape = (N, 60, 1))
TIMESTEPS = int(X.shape[1])  # = 60

# Arsitektur yang kamu kirim (64 -> 32 -> Dense(1))
inputs = Input(shape=(TIMESTEPS, 1), name="input_layer")
x = layers.LSTM(64, return_sequences=True, name="lstm")(inputs)
x = layers.Dropout(0.2, name="dropout")(x)
x = layers.LSTM(32, return_sequences=False, name="lstm_1")(x)
x = layers.Dropout(0.2, name="dropout_1")(x)
outputs = layers.Dense(1, name="dense")(x)

model = Model(inputs, outputs, name="lstm_close_1d")
model.compile(optimizer="adam", loss="mse")
model.summary()
# Out:
# Model: "lstm_close_1d"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 60, 1)]           0
#
#  lstm (LSTM)                 (None, 60, 64)            16896
#
#  dropout (Dropout)           (None, 60, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 29,345
# Trainable params: 29,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
# EarlyStopping: hentikan saat val_loss tidak turun lagi (restore best weights)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# Optional: kurangi learning rate saat stuck
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

callbacks = [early_stop, reduce_lr]

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
callbacks = [early_stop, reduce_lr]

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    shuffle=False,    # penting untuk time series
    callbacks=callbacks,
    verbose=2
)
# Out:
# Epoch 1/100
# 70/70 - 11s - loss: 0.0032 - val_loss: 0.0101 - lr: 0.0010 - 11s/epoch - 159ms/step
# Epoch 2/100
# 70/70 - 4s - loss: 0.0039 - val_loss: 0.0089 - lr: 0.0010 - 4s/epoch - 54ms/step
# Epoch 3/100
# 70/70 - 4s - loss: 0.0025 - val_loss: 0.0022 - lr: 0.0010 - 4s/epoch - 53ms/step
# Epoch 4/100
# 70/70 - 4s - loss: 7.6934e-04 - val_loss: 9.8945e-04 - lr: 0.0010 - 4s/epoch - 55ms/step
# Epoch 5/100
# 70/70 - 4s - loss: 0.0013 - val_loss: 0.0011 - lr: 0.0010 - 4s/epoch - 53ms/step
# Epoch 6/100
# 70/70 - 4s - loss: 6.8902e-04 - val_loss: 0.0013 - lr: 0.0010 - 4s/epoch - 55ms/step
# Epoch 7/100
# 70/70 - 4s - loss: 0.0012 - val_loss: 8.8319e-04 - lr: 0.0010 - 4s/epoch - 53ms/step
# Epoch 8/100
# 70/70 - 4s - loss: 6.2769e-04 - val_loss: 8.7581e-04 - lr: 0.0010 - 4s/epoch - 53ms/step
# Epoch 9/100
# 70/70 - 4s - loss: 7.6521e-04 - val_loss: 0.0012 - lr: 0.0010 - 4s/epoch - 60ms/step
# Epoch 10/100
# 70/70 - 4s - loss: 6.7446e-04 - val_loss: 0.0011 - lr: 0.0010 - 4s/epoch - 55ms/step
# Epoch 11/100
# 70/70 - 4s - loss: 7.0505e-04 - val_loss: 0.0016 - lr: 0.0010 - 4s/epoch - 56ms/step
# Epoch 12/100
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 70/70 - 4s - loss: 6.6157e-04 - val_loss: 0.0015 - lr: 0.0010 - 4s/epoch - 59ms/step
# Epoch 13/100
# 70/70 - 4s - loss: 6.7824e-04 - val_loss: 0.0015 - lr: 5.0000e-04 - 4s/epoch - 59ms/step
# Epoch 14/100
# 70/70 - 4s - loss: 6.5052e-04 - val_loss: 0.0011 - lr: 5.0000e-04 - 4s/epoch - 58ms/step
# Epoch 15/100
# 70/70 - 4s - loss: 5.6172e-04 - val_loss: 0.0016 - lr: 5.0000e-04 - 4s/epoch - 56ms/step
# Epoch 16/100
# 70/70 - 4s - loss: 5.9725e-04 - val_loss: 8.2251e-04 - lr: 5.0000e-04 - 4s/epoch - 56ms/step
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 70/70 - 4s - loss: 5.5710e-04 - val_loss: 9.2511e-04 - lr: 5.0000e-04 - 4s/epoch - 58ms/step
# Epoch 18/100
# 70/70 - 4s - loss: 5.5606e-04 - val_loss: 0.0019 - lr: 2.5000e-04 - 4s/epoch - 55ms/step
# Epoch 19/100
# 70/70 - 4s - loss: 5.6205e-04 - val_loss: 0.0017 - lr: 2.5000e-04 - 4s/epoch - 54ms/step
# Epoch 20/100
# 70/70 - 4s - loss: 4.4133e-04 - val_loss: 0.0020 - lr: 2.5000e-04 - 4s/epoch - 57ms/step
# Epoch 21/100
# 70/70 - 4s - loss: 4.7142e-04 - val_loss: 0.0020 - lr: 2.5000e-04 - 4s/epoch - 59ms/step
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 70/70 - 4s - loss: 4.9251e-04 - val_loss: 0.0018 - lr: 2.5000e-04 - 4s/epoch - 63ms/step
# Epoch 23/100
# 70/70 - 4s - loss: 4.7833e-04 - val_loss: 0.0032 - lr: 1.2500e-04 - 4s/epoch - 63ms/step
# Epoch 24/100
# 70/70 - 6s - loss: 5.5201e-04 - val_loss: 0.0028 - lr: 1.2500e-04 - 6s/epoch - 82ms/step
# Epoch 25/100
# 70/70 - 4s - loss: 5.4186e-04 - val_loss: 0.0025 - lr: 1.2500e-04 - 4s/epoch - 62ms/step
# Epoch 26/100
# Restoring model weights from the end of the best epoch: 16.
# 70/70 - 4s - loss: 5.8428e-04 - val_loss: 0.0027 - lr: 1.2500e-04 - 4s/epoch - 56ms/step
# Epoch 26: early stopping

# %%
best_epoch = int(np.argmin(history.history['val_loss']) + 1)
print(f"Best epoch (val_loss minimal) = {best_epoch}")

plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Perbandingan Loss (Train vs Validation)')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True); plt.show()
# Out:
# Best epoch (val_loss minimal) = 16

# %%
y_pred_scaled = model.predict(X_val, verbose=0)
y_val_inv = scaler.inverse_transform(y_val.reshape(-1,1))
y_pred_inv = scaler.inverse_transform(y_pred_scaled)

rmse = mean_squared_error(y_val_inv, y_pred_inv, squared=False)
mae  = mean_absolute_error(y_val_inv, y_pred_inv)
print(f"RMSE: {rmse:.2f} | MAE: {mae:.2f}")

plt.figure(figsize=(14,6))
plt.plot(y_val_inv, label='Asli', linewidth=1.2)
plt.plot(y_pred_inv, label='Prediksi', linewidth=1.2)
plt.title('Asli vs Prediksi (Validation Set)')
plt.xlabel('Index'); plt.ylabel('Harga (USD)'); plt.legend(); plt.grid(True); plt.show()

# plot dengan tanggal (opsional)
dates = data.index[TIMESTEPS + train_size : TIMESTEPS + train_size + len(y_val_inv)]
plt.figure(figsize=(14,6))
plt.plot(dates, y_val_inv.flatten(), label='Asli')
plt.plot(dates, y_pred_inv.flatten(), label='Prediksi')
plt.title('Asli vs Prediksi (Dengan Tanggal)')
plt.xlabel('Tanggal'); plt.ylabel('Harga (USD)'); plt.legend(); plt.grid(True); plt.show()
# Out:
# RMSE: 3483.04 | MAE: 2705.34

# %%
# Simpan scaler
joblib.dump(scaler, SCALER_PATH)

# Bersihkan SavedModel lama
if os.path.isdir(MODEL_SAVED):
    shutil.rmtree(MODEL_SAVED)

# Simpan full H5 (bukan weights-only) dan SavedModel
model.save(MODEL_H5, include_optimizer=False)
model.save(MODEL_SAVED, save_format="tf")

print("Saved H5:", MODEL_H5)
print("Saved SavedModel:", MODEL_SAVED)
print("Saved Scaler:", SCALER_PATH)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: c:\Users\X395\kuliah semester 5\TUGAS 4\model_saved_tf\assets
# INFO:tensorflow:Assets written to: c:\Users\X395\kuliah semester 5\TUGAS 4\model_saved_tf\assets
# Saved H5: c:\Users\X395\kuliah semester 5\TUGAS 4\lstm_btc_daily_model.h5
# Saved SavedModel: c:\Users\X395\kuliah semester 5\TUGAS 4\model_saved_tf
# Saved Scaler: c:\Users\X395\kuliah semester 5\TUGAS 4\scaler_minmax.joblib
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
